# %% [markdown]
# # As part of Kaggle competition

# %% [markdown]
# Focus of this notebook is for me to learn pandas :)

# %%
# Import data manipulation libraries
import pandas as pd
import numpy as np
import datetime

# Visualization libaries
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# Machine Learning
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import tree
from sklearn.linear_model import SGDRegressor

# %%
train_data = pd.read_csv("train.csv")
test_data = pd.read_csv("test.csv")

# %%
train_data.head()
# Out:
#          date  store  item  sales
# 0  2013-01-01      1     1     13
# 1  2013-01-02      1     1     11
# 2  2013-01-03      1     1     14
# 3  2013-01-04      1     1     13
# 4  2013-01-05      1     1     10

# %%
all_data = [test_data, train_data]

# %% [markdown]
# Define more readable features

# %%
for dataset in all_data:
    dataset['date'] = pd.to_datetime(dataset['date'])
    dataset['year'] = dataset.date.dt.year
    dataset['month'] = dataset.date.dt.month
    dataset['day'] = dataset.date.dt.day
    dataset['day_of_year'] = dataset.date.dt.dayofyear
    dataset['day_of_week'] = dataset.date.dt.dayofweek
    dataset['week_of_year'] = dataset.date.dt.weekofyear
    
    dataset.drop('date', axis=1, inplace=True)

# %%
train_data['daily_avg'] = train_data.groupby(['item','store','day_of_week'])['sales'].transform('mean')
train_data['monthly_avg'] = train_data.groupby(['item','store','month'])['sales'].transform('mean')
train_data = train_data.dropna()

# %%
train_data.head()
# Out:
#    store  item  sales  year  month  day  day_of_year  day_of_week  \
# 0      1     1     13  2013      1    1            1            1
# 1      1     1     11  2013      1    2            2            2
# 2      1     1     14  2013      1    3            3            3
# 3      1     1     13  2013      1    4            4            4
# 4      1     1     10  2013      1    5            5            5
#
#    week_of_year  daily_avg  monthly_avg
# 0             1  18.168582    13.709677
# 1             1  18.793103    13.709677
# 2             1  19.452107    13.709677
# 3             1  21.015326    13.709677
# 4             1  22.973180    13.709677

# %%
daily_avg = train_data.groupby(['item','store','day_of_week'])['sales'].mean().reset_index()
monthly_avg = train_data.groupby(['item','store','month'])['sales'].mean().reset_index()

# %%
def merge(x,y,col,col_name):
    x =pd.merge(x, y, how='left', on=None, left_on=col, right_on=col,\
                left_index=False, right_index=False, sort=True,copy=True, \
                indicator=False)
    x=x.rename(columns={'sales':col_name})
    return x

test_data = merge(test_data, daily_avg,['item','store','day_of_week'],'daily_avg')
test_data = merge(test_data, monthly_avg,['item','store','month'],'monthly_avg')

# %%
test_data.head()
# Out:
#    id  store  item  year  month  day  day_of_year  day_of_week  week_of_year  \
# 0   0      1     1  2018      1    1            1            0             1
# 1   7      1     1  2018      1    8            8            0             2
# 2  14      1     1  2018      1   15           15            0             3
# 3  21      1     1  2018      1   22           22            0             4
# 4  28      1     1  2018      1   29           29            0             5
#
#    daily_avg  monthly_avg
# 0  15.584615    13.709677
# 1  15.584615    13.709677
# 2  15.584615    13.709677
# 3  15.584615    13.709677
# 4  15.584615    13.709677

# %%
train_data.head()
# Out:
#    store  item  sales  year  month  day  day_of_year  day_of_week  \
# 0      1     1     13  2013      1    1            1            1
# 1      1     1     11  2013      1    2            2            2
# 2      1     1     14  2013      1    3            3            3
# 3      1     1     13  2013      1    4            4            4
# 4      1     1     10  2013      1    5            5            5
#
#    week_of_year  daily_avg  monthly_avg
# 0             1  18.168582    13.709677
# 1             1  18.793103    13.709677
# 2             1  19.452107    13.709677
# 3             1  21.015326    13.709677
# 4             1  22.973180    13.709677

# %%
# Adding rolling mean feature to train
df = train_data.groupby(['item'])['sales'].rolling(10).mean().reset_index().drop('level_1', axis=1)
train_data['rolling_mean'] = df['sales']

# Adding last 3 months of rolling mean from training to test data 
# (Doing this and shifting rolling mean 3 months in training data)
rolling_mean_test = train_data.groupby(['item','store'])['rolling_mean'].tail(90).copy().reset_index().drop('index', axis=1)
test_data['rolling_mean'] = rolling_mean_test

# Shifting rolling mean 3 months
train_data['rolling_mean'] = train_data.groupby(['item'])['rolling_mean'].shift(90)
train_data.tail()
# Out:
#         store  item  sales  year  month  day  day_of_year  day_of_week  \
# 912995     10    50     63  2017     12   27          361            2
# 912996     10    50     59  2017     12   28          362            3
# 912997     10    50     74  2017     12   29          363            4
# 912998     10    50     62  2017     12   30          364            5
# 912999     10    50     82  2017     12   31          365            6
#
#         week_of_year  daily_avg  monthly_avg  rolling_mean
# 912995            52  68.823755    56.283871          84.2
# 912996            52  73.532567    56.283871          84.8
# 912997            52  78.275862    56.283871          87.9
# 912998            52  82.854406    56.283871          88.9
# 912999            52  87.984674    56.283871          86.3

# %%
colormap = plt.cm.RdBu
plt.figure(figsize=(14,12))
plt.title('Pearson Correlation of Features', y=1.05, size=15)
sns.heatmap(train_data.corr(),linewidths=0.1,vmax=1.0, 
            square=True, cmap=colormap, linecolor='white', annot=True)

# %%
# Seems like dayofyear and weekofyear has high internal correlation and correlates highly with month, so let's drop those.
# All average/mean features also correlated heavily. Since Monthly Average correlates most with sales, we keep this.
combine = [train_data, test_data]

for dataset in combine:
    dataset.drop(['day_of_year','week_of_year','daily_avg','day','month','item','store'],axis=1,inplace=True)
    
# Let's check the correlation with all dropped features
colormap = plt.cm.RdBu
plt.figure(figsize=(14,12))
plt.title('Pearson Correlation of Features', y=1.05, size=15)
sns.heatmap(train_data.corr(),linewidths=0.1,vmax=1.0, 
            square=True, cmap=colormap, linecolor='white', annot=True)

train_data.tail()
# Out:
#         sales  year  day_of_week  monthly_avg  rolling_mean
# 912995     63  2017            2    56.283871          84.2
# 912996     59  2017            3    56.283871          84.8
# 912997     74  2017            4    56.283871          87.9
# 912998     62  2017            5    56.283871          88.9
# 912999     82  2017            6    56.283871          86.3

# %%
train_data.head()
# Out:
#    sales  year  day_of_week  monthly_avg  rolling_mean
# 0     13  2013            1    13.709677           NaN
# 1     11  2013            2    13.709677           NaN
# 2     14  2013            3    13.709677           NaN
# 3     13  2013            4    13.709677           NaN
# 4     10  2013            5    13.709677           NaN

# %%
matrix = train_data.dropna().as_matrix()
x = matrix[:,1:]
y = matrix[:,0]

# %% [markdown]
# Now we have a good foundation wih useful features we can feed into LSTM networks to try to predict sales.
